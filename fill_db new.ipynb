# %%
import sqlalchemy

db = 'postgresql://music:Start123@localhost:5433/music'
engine = sqlalchemy.create_engine(db)
connection = engine.connect()

connection.execute("""INSERT INTO executor (executor_name, surname, alias)
    VALUES ('Люся', 'Чеботина', 'Люся Чеботина'), 
    ('Олег', 'Анофриев', 'Олег Анофриев'), 
    ('Леонид', 'Агутин', 'Леонид Агутин'), 
    ('Константин', 'Никольский', 'Константин Никольский'), 
    ('Орден', 'Славы', 'Орден Славы'), 
    ('Tom', 'Walker', 'Tom Walker'), 
    ('Jacob', 'Banks', 'Jacob Banks'), 
    ('Bishop', 'Briggs', 'Bishop Briggs')
    ;""" )

print ("Исполнители записаны")

# %%
print(connection.execute("""SELECT * FROM executor;""" ).fetchall())

# %%
connection.execute("""INSERT INTO genre (genre_name)
    VALUES ('ruspop'), 
    ('pop'), 
    ('rusestrada'), 
    ('rusrock'), 
    ('foreignbard'), 
    ('indie'), 
    ('rnb')
    ;""")

print ("Жанры записаны")

# %%
print(connection.execute("""SELECT * FROM genre;""" ).fetchall())

# %%
connection.execute("""INSERT INTO executorgenre (id_executor, id_genre)
    VALUES (1, 1),
    (2, 3),
    (3, 3),
    (4, 4),
    (5, 4),
    (6, 5),
    (7, 7),
    (8, 6)
;""")

print ("Готово")

# %%
print(connection.execute("""SELECT * FROM executorgenre;""" ).fetchall())

# %%
connection.execute("""INSERT INTO album (album_name, release_year)
    VALUES ('The End', '2021'),
        ('Избранное', '2019'),
        ('Золотая коллекция', '2017'),
        ('La Vida Cosmopolita', '2020'),
        ('Мне только снится жизнь моя', '2018'),
        ('Аллилуия', '2019'),
        ('What a Time To Be Alive', '2019'),
        ('Blessings - EP', '2017'),
        ('Village', '2018'),
        ('CHAMPION', '2019')
    ;""")

print ("Готово")

# %%
print(connection.execute("""SELECT * FROM album;""" ).fetchall())

# %%
connection.execute("""INSERT INTO executoralbum (id_executor, id_album)
    VALUES (1, 2),
    (2, 4),
    (3, 5),
    (4, 6),
    (5, 7),
    (6, 9),
    (7, 10),
    (8, 11)
    ;""")

print ("Готово")

# %%
connection.execute("""INSERT INTO track (track_name, duration, id_album)
    VALUES ('Песенка шофёра', '185280', 4),
 ('Песенка ни о чём', '169400', 4),
 ('Есть только миг', '221930', 4),
 ('А сердце так стучит...', '119110', 4),
 ('Песня о друге', '198920', 4),
 ('Песенка почтальона', '175120', 4),
 ('Мы сдадим последние экзамены', '164850', 4),
 ('Дороги', '89730', 4),
 ('Бежит, бежит машина', '199910', 4),
 ('Это было недавно', '163080', 4),
 ('На лесной просеке (Тер-ри-кон)', '195730', 4),
 ('Мы жили по соседству', '186170', 4),
 ('В морозный вечер', '145860', 4),
 ('Футбольный мяч', '153620', 4),
 ('Всё было (И солнце всходило)', '199150', 4),
 ('Палуба', '124470', 4),
 ('Колыбельная', '202940', 4),
 ('Аэлита', '156910', 4),
 ('Море', '120320', 4),
 ('Весенняя песенка', '162260', 4),
 ('Песенка о робинзонах', '176080', 4),
 ('Солдатское письмо', '213190', 4),
 ('Всё скорее', '180920', 4),
 ('Funky Cha', '211590', 5),
 ('Quédate', '206700', 5),
 ('Y Quién Eres Tú', '210330', 5),
 ('Just a Rainy Day', '267390', 5),
 ('Viva la Noche en New York', '253360', 5),
 ('Sólo por Ti Regresaré', '230290', 5),
 ('Ella', '192410', 5),
 ('Sobreviviré', '205760', 5),
 ('Father is Near You', '241340', 5),
 ('Enamorado', '210130', 5),
 ('Mágico Amor', '190640', 5),
 ('Мне только снится жизнь моя', '326260', 6),
 ('Облако', '178150', 6),
 ('Зеркало мира', '310230', 6),
 ('Один взгляд назад', '219950', 6),
 ('Ночная птица', '262060', 6),
 ('Мой друг художник и поэт', '367380', 6),
 ('Птицы белые мои', '280860', 6),
 ('Музыкант', '319080', 6),
 ('Я сам из тех', '235990', 6),
 ('Воскресенье', '385670', 6),
 ('Прошедший день', '314820', 6),
 ('Я бреду по бездорожью', '344050', 6),
 ('От любви к любви', '331440', 6),
 ('Без цели и без расчета', '308370', 6),
 ('Растаяла дымка сквозная', '359180', 6),
 ('Герои', '301600', 7),
 ('Кровавая река', '240210', 7),
 ('Идиот', '228660', 7),
 ('К ангелам', '268780', 7),
 ('1915', '330810', 7),
 ('Чудное мгновенье', '252410', 7),
 ('Чудное мгновенье 2', '288770', 7),
 ('Дети сидят в интернете', '270200', 7),
 ('Если я стану рыбой', '300300', 7),
 ('Аллилуия, София!', '241520', 7),
 ('Вечное молчание', '252170', 7),
 ('Звезда небосвода', '306920', 7),
 ('Поэт и правитель', '250220', 7),
 ('Just You and I', '198010', 8),
 ('Leave a Light On', '218260', 8),
 ('Better Half of Me', '195410', 8),
 ('Not Giving In', '228850', 8),
 ('How Can You Sleep at Night?', '216130', 8),
 ('Angels', '208970', 8),
 ('Blessings', '196990', 9),
 ('Karma', '183710', 9),
 ('Rapture', '186030', 9),
 ('Play Dead', '234050', 9),
 ('Chainsmoking', '195100', 10),
 ('I STILL LOVE YOU', '83460', 11),
 ('CAN YOU HEAR ME NOW?', '179440', 11),
 ('CHAMPION', '173120', 11),
 ('TATTOOED ON MY HEART', '201330', 11),
 ('SOMEONE ELSE', '211440', 11),
 ('JEKYLL & HIDE', '196340', 11),
 ('LONELY', '180640', 11),
 ('WILD', '144010', 11),
 ('MY SHINE', '192930', 11),
 ('I TRIED', '158280', 11),
 ('Солнце Монако', '160000', 2),
 ('Амур', '185910', 2),
 ('8', '146330', 2),
 ('Your Kiss', '60870', 2),
 ('Награда', '152720', 2),
 ('О2', '158260', 2),
 ('Плохие люди', '141330', 2),
 ('Soundtrack', '100650', 2)
 ;""")

print ("Готово")

# %%
connection.execute("""INSERT INTO collection (name_collection, release_year)
    VALUES ('Весна 2018', 2018),
    ('Сборка TOP', 2019),
    ('Лучшие новинки', 2017),
    ('The Best 2020', 2020),
    ('Summer HITS 2020', 2020),
    ('Happy New Year', 2021),
    ('Разное', 2018),
    ('Чего-то там...', 2019)

    ;""")

# %%
print(connection.execute("""SELECT * FROM collection;""" ).fetchall())

# %%
connection.execute("""INSERT INTO albumtrackcollection (id_collection, id_track)
    VALUES (1, 4),
    (1, 35),
    (1, 6),
    (1, 15),
    (2, 7),
    (2, 9),
    (2, 10),
    (3, 11),
    (3, 25),
    (3, 26),
    (3, 33),
    (4, 34),
    (4, 59),
    (4, 47),
    (4, 15),
    (4, 42),
    (5, 36),
    (5, 23),
    (5, 38),
    (6, 41),
    (6, 22),
    (6, 60),
    (6, 12),
    (7, 47),
    (7, 52),
    (8, 13),
    (8, 44),
    (8, 11)


;""")
